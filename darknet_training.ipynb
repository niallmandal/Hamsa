# %%
import zipfile
from google.colab import drive

drive.mount('/content/drive/', force_remount=True)

zip_ref = zipfile.ZipFile("/content/drive/My Drive/yolo/darknet1-no-make.zip", 'r')
zip_ref.extractall("/tmp")
zip_ref.close()
# Out:
# Mounted at /content/drive/

# %%
# %cd ../tmp/darknet
# !make
# Out:
# /tmp/darknet
# chmod +x *.sh
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/image_opencv.cpp -o obj/image_opencv.o
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/http_stream.cpp -o obj/http_stream.o
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:243:21: warning: unused variable ‘n’ [-Wunused-variable]
#                  int n = _write(client, outputbuf, outlen);
#                      ^
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘convolution_2d’:
# ...

# %%
# !wget https://pjreddie.com/media/files/yolov3-tiny.weights
# !./darknet partial cfg/yolov3-tiny.cfg yolov3-tiny.weights yolov3-tiny.conv.15 15
# Out:
# --2019-11-13 06:17:27--  https://pjreddie.com/media/files/yolov3-tiny.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35434956 (34M) [application/octet-stream]
# Saving to: ‘yolov3-tiny.weights.1’
#
# yolov3-tiny.weights 100%[===================>]  33.79M  41.0MB/s    in 0.8s
#
# 2019-11-13 06:17:28 (41.0 MB/s) - ‘yolov3-tiny.weights.1’ saved [35434956/35434956]
#
#    layer   filters  size/strd(dil)      input                output
#    0 conv     16       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  16 0.150 BF
#    1 max                2x 2/ 2    416 x 416 x  16 ->  208 x 208 x  16 0.003 BF
#    2 conv     32       3 x 3/ 1    208 x 208 x  16 ->  208 x 208 x  32 0.399 BF
#    3 max                2x 2/ 2    208 x 208 x  32 ->  104 x 104 x  32 0.001 BF
# ...

# %%
# %%capture
# !./darknet detector train data/obj.data cfg/yolov3-tiny0.cfg yolov3-tiny.conv.15

# %%
# %cd ../../content
# !zip -r "/content/drive/My Drive/darknet1-trained-tiny-weights.zip" "../tmp/darknet"
# Out:
# /content
#   adding: ../tmp/darknet/ (stored 0%)
#   adding: ../tmp/darknet/obj/ (stored 0%)
#   adding: ../tmp/darknet/obj/gru_layer.o (deflated 66%)
#   adding: ../tmp/darknet/obj/rnn_layer.o (deflated 66%)
#   adding: ../tmp/darknet/obj/im2col.o (deflated 50%)
#   adding: ../tmp/darknet/obj/dropout_layer.o (deflated 57%)
#   adding: ../tmp/darknet/obj/yolo.o (deflated 65%)
#   adding: ../tmp/darknet/obj/super.o (deflated 66%)
#   adding: ../tmp/darknet/obj/maxpool_layer_kernels.o (deflated 78%)
#   adding: ../tmp/darknet/obj/convolutional_layer.o (deflated 60%)
#   adding: ../tmp/darknet/obj/activation_kernels.o (deflated 74%)
#   adding: ../tmp/darknet/obj/classifier.o (deflated 69%)
#   adding: ../tmp/darknet/obj/rnn_vid.o (deflated 71%)
#   adding: ../tmp/darknet/obj/tag.o (deflated 64%)
#   adding: ../tmp/darknet/obj/sam_layer.o (deflated 58%)
#   adding: ../tmp/darknet/obj/route_layer.o (deflated 66%)
#   adding: ../tmp/darknet/obj/compare.o (deflated 65%)
# ...
